# %% [markdown]
# # Notebook 16: Gradient Boosting
#
# **Module:** 03 Classical ML
# **Part:** Ensemble Methods
# **Duration:** ~2 hrs
#
# ---
#
# ## Learning Objectives
#
# 1. Understand Gradient Boosting
# 2. Train and evaluate
# 3. Know key hyperparameters

# %% [markdown]
# ## 1. Overview
#
# Fit each tree to residuals of previous ensemble.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

REPO = Path('../../').resolve()
plt.rcParams['figure.figsize'] = (8, 5)
rng = np.random.default_rng(42)

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier(n_estimators=100, max_depth=3, learning_rate=0.1, random_state=42)
gb.fit(X_train, y_train)
print(f'GradientBoosting accuracy: {gb.score(X_test, y_test):.4f}')

# %% [markdown]
# ## Hyperparameters
#
# See sklearn/xgboost documentation. Key: `n_estimators`, `learning_rate`, `max_depth`.

# %% [markdown]
# ---
#
# ## Summary
#
# Gradient Boosting is a powerful ensemble method for tabular data competitions.
#
# **Next:** [17_Gradient_Boosting.ipynb](17_Gradient_Boosting.ipynb)
