# %% [markdown]
# # Notebook 28: Feature Engineering
#
# **Module:** 03 Classical ML
# **Part:** Model Selection
# **Duration:** ~2 hrs
#
# ---
#
# ## Learning Objectives
#
# 1. Create polynomial, interaction, binning features
# 2. Encode categoricals
# 3. Handle datetime and text basics

# %% [markdown]
# ## Techniques
#
# - Polynomial / interaction features
# - Log / sqrt transforms for skewed data
# - One-hot / target encoding
# - Domain-specific features (GIS: area, perimeter, shape index)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

REPO = Path('../../').resolve()
plt.rcParams['figure.figsize'] = (8, 5)
rng = np.random.default_rng(42)

# %%
titanic = pd.read_csv(REPO / 'TitanicSurvival.csv')

df = titanic.copy()
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
df['IsAlone'] = (df['FamilySize'] == 1).astype(int)
df = pd.get_dummies(df, columns=['Sex', 'Embarked'], drop_first=True)
print(df[['FamilySize','IsAlone']].head())
print('\nNew columns:', [c for c in df.columns if c not in titanic.columns])

# %% [markdown]
# ---
#
# ## Summary
#
# Feature engineering often beats algorithm tuning.
#
# **Next:** [29_Feature_Selection.ipynb](29_Feature_Selection.ipynb)
