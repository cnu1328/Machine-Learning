# %% [markdown]
# # Notebook 17: XGBoost
#
# **Module:** 03 Classical ML
# **Part:** Ensemble Methods
# **Duration:** ~2 hrs
#
# ---
#
# ## Learning Objectives
#
# 1. Understand XGBoost
# 2. Train and evaluate
# 3. Know key hyperparameters

# %% [markdown]
# ## 1. Overview
#
# Optimized gradient boosting with regularization.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

REPO = Path('../../').resolve()
plt.rcParams['figure.figsize'] = (8, 5)
rng = np.random.default_rng(42)

# %%
try:
    import xgboost as xgb
    xg = xgb.XGBClassifier(n_estimators=100, max_depth=4, learning_rate=0.1, random_state=42, eval_metric='logloss')
    xg.fit(X_train, y_train)
    print(f'XGBoost accuracy: {xg.score(X_test, y_test):.4f}')
except ImportError:
    print('Install xgboost: pip install xgboost')

# %% [markdown]
# ## Hyperparameters
#
# See sklearn/xgboost documentation. Key: `n_estimators`, `learning_rate`, `max_depth`.

# %% [markdown]
# ---
#
# ## Summary
#
# XGBoost is a powerful ensemble method for tabular data competitions.
#
# **Next:** [18_XGBoost.ipynb](18_XGBoost.ipynb)
