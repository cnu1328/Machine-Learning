# %% [markdown]
# # Notebook 15: AdaBoost
#
# **Module:** 03 Classical ML
# **Part:** Ensemble Methods
# **Duration:** ~2 hrs
#
# ---
#
# ## Learning Objectives
#
# 1. Understand AdaBoost
# 2. Train and evaluate
# 3. Know key hyperparameters

# %% [markdown]
# ## 1. Overview
#
# Sequential ensemble weighting misclassified samples.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

REPO = Path('../../').resolve()
plt.rcParams['figure.figsize'] = (8, 5)
rng = np.random.default_rng(42)

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

ada = AdaBoostClassifier(DecisionTreeClassifier(max_depth=1), n_estimators=50, random_state=42)
ada.fit(X_train, y_train)
print(f'AdaBoost accuracy: {ada.score(X_test, y_test):.4f}')

# %% [markdown]
# ## Hyperparameters
#
# See sklearn/xgboost documentation. Key: `n_estimators`, `learning_rate`, `max_depth`.

# %% [markdown]
# ---
#
# ## Summary
#
# AdaBoost is a powerful ensemble method for tabular data competitions.
#
# **Next:** [16_AdaBoost.ipynb](16_AdaBoost.ipynb)
