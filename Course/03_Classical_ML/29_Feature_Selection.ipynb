# %% [markdown]
# # Notebook 29: Feature Selection
#
# **Module:** 03 Classical ML
# **Part:** Model Selection
# **Duration:** ~2 hrs
#
# ---
#
# ## Learning Objectives
#
# 1. Filter, wrapper, embedded methods
# 2. Apply RFE and L1 regularization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

REPO = Path('../../').resolve()
plt.rcParams['figure.figsize'] = (8, 5)
rng = np.random.default_rng(42)

# %%
from sklearn.feature_selection import RFE, SelectFromModel
from sklearn.linear_model import LogisticRegression

X_f = df.select_dtypes(include=[np.number]).drop(columns=['Survived'], errors='ignore').fillna(0)
y_f = df['Survived']

rfe = RFE(LogisticRegression(max_iter=1000), n_features_to_select=5)
rfe.fit(X_f, y_f)
print('Selected:', list(X_f.columns[rfe.support_]))

# %% [markdown]
# ---
#
# ## Summary
#
# Remove redundant features to reduce overfitting and training time.
#
# **Next:** [30_Cross_Validation.ipynb](30_Cross_Validation.ipynb)
