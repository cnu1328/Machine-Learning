# %% [markdown]
# # Notebook 23: Gaussian Mixture Models
#
# **Module:** 03 Classical ML
# **Part:** Clustering
# **Duration:** ~2 hrs
#
# ---
#
# ## Learning Objectives
#
# 1. Understand soft clustering with EM
# 2. Compare GMM vs K-Means

# %% [markdown]
# ## Model
#
# $$p(x) = \sum_{k=1}^{K} \pi_k \mathcal{N}(x | \mu_k, \Sigma_k)$$
#
# EM algorithm alternates E-step (responsibilities) and M-step (update parameters).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

REPO = Path('../../').resolve()
plt.rcParams['figure.figsize'] = (8, 5)
rng = np.random.default_rng(42)

# %%
from sklearn.mixture import GaussianMixture

gmm = GaussianMixture(n_components=3, random_state=42).fit(X)
print('Converged:', gmm.converged_)
print('BIC:', gmm.bic(X))

# %% [markdown]
# ---
#
# ## Summary
#
# GMM provides soft cluster assignments and probabilistic framework.
#
# **Next:** [24_PCA.ipynb](24_PCA.ipynb)
