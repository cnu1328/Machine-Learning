# %% [markdown]
# # Notebook 27: UMAP
#
# **Module:** 03 Classical ML
# **Part:** Dimensionality Reduction
# **Duration:** ~2 hrs
#
# ---
#
# ## Learning Objectives
#
# 1. Compare UMAP vs t-SNE
# 2. Use for visualization and preprocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

REPO = Path('../../').resolve()
plt.rcParams['figure.figsize'] = (8, 5)
rng = np.random.default_rng(42)

# %%
try:
    import umap
    X_umap = umap.UMAP(n_components=2, random_state=42).fit_transform(X_sub)
    plt.scatter(X_umap[:,0], X_umap[:,1], c=y_sub, cmap='viridis', alpha=0.7)
    plt.title('UMAP — Iris'); plt.show()
except ImportError:
    print('Install umap-learn: pip install umap-learn')

# %% [markdown]
# ---
#
# ## Summary
#
# UMAP is faster than t-SNE and preserves more global structure.
#
# **Next:** [28_Feature_Engineering.ipynb](28_Feature_Engineering.ipynb)
