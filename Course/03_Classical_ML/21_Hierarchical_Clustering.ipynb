# %% [markdown]
# # Notebook 21: Hierarchical Clustering
#
# **Module:** 03 Classical ML
# **Part:** Clustering
# **Duration:** ~2 hrs
#
# **Legacy script:** `Day - 20 Clustering income spent using Hierarchial clustering.py`
#
# ---
#
# ## Learning Objectives
#
# 1. Understand agglomerative clustering
# 2. Read dendrograms
# 3. Walk through Day - 20 script

# %% [markdown]
# ## Linkage Methods
#
# - **Single:** min distance between clusters
# - **Complete:** max distance
# - **Ward:** minimize variance increase

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

REPO = Path('../../').resolve()
plt.rcParams['figure.figsize'] = (8, 5)
rng = np.random.default_rng(42)

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.datasets import load_iris

X = load_iris().data[:50]
Z = linkage(X, method='ward')

plt.figure(figsize=(10, 5))
dendrogram(Z)
plt.title('Hierarchical Clustering Dendrogram'); plt.xlabel('Sample'); plt.ylabel('Distance'); plt.show()

# %% [markdown]
# ---
#
# ## Summary
#
# Hierarchical clustering needs no k upfront; dendrogram shows cluster structure.
#
# **Next:** [22_DBSCAN.ipynb](22_DBSCAN.ipynb)
