# %% [markdown]
# # Notebook 05: Random Forest Regression
#
# **Module:** 03 Classical ML
# **Part:** Regression
# **Duration:** ~2 hrs
#
# **Legacy script:** `Day - 16 Car price Prediction using Random Forest REgression.py`
#
# ---
#
# ## Learning Objectives
#
# 1. Understand bagging and ensemble averaging
# 2. Train random forest regressor
# 3. Interpret feature importance

# %% [markdown]
# ## 1. Random Forest = Bagging + Random Subspaces
#
# 1. Train $B$ trees on bootstrap samples
# 2. At each split, consider random subset of features
# 3. Predict by averaging all tree outputs
#
# $$\hat{f}(x) = \frac{1}{B}\sum_{b=1}^{B} T_b(x)$$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

REPO = Path('../../').resolve()
plt.rcParams['figure.figsize'] = (8, 5)
rng = np.random.default_rng(42)

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=100, max_depth=8, random_state=42)
rf.fit(X_train, y_train)
print(f'RF R² test: {rf.score(X_test, y_test):.4f}')

importances = rf.feature_importances_
plt.barh(data.feature_names, importances)
plt.xlabel('Importance'); plt.title('Random Forest Feature Importance'); plt.show()

# %% [markdown]
# ---
#
# ## Summary
#
# Random Forest reduces variance through ensemble averaging.
#
# **Next:** [06_Regression_Model_Evaluation.ipynb](06_Regression_Model_Evaluation.ipynb)
