# %% [markdown]
# # Notebook 18: LightGBM
#
# **Module:** 03 Classical ML
# **Part:** Ensemble Methods
# **Duration:** ~2 hrs
#
# ---
#
# ## Learning Objectives
#
# 1. Understand LightGBM
# 2. Train and evaluate
# 3. Know key hyperparameters

# %% [markdown]
# ## 1. Overview
#
# Leaf-wise tree growth for speed.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

REPO = Path('../../').resolve()
plt.rcParams['figure.figsize'] = (8, 5)
rng = np.random.default_rng(42)

# %%
try:
    import lightgbm as lgb
    lgbm = lgb.LGBMClassifier(n_estimators=100, max_depth=4, random_state=42, verbose=-1)
    lgbm.fit(X_train, y_train)
    print(f'LightGBM accuracy: {lgbm.score(X_test, y_test):.4f}')
except ImportError:
    print('Install lightgbm: pip install lightgbm')

# %% [markdown]
# ## Hyperparameters
#
# See sklearn/xgboost documentation. Key: `n_estimators`, `learning_rate`, `max_depth`.

# %% [markdown]
# ---
#
# ## Summary
#
# LightGBM is a powerful ensemble method for tabular data competitions.
#
# **Next:** [19_LightGBM.ipynb](19_LightGBM.ipynb)
