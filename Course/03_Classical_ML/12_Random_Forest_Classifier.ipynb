# %% [markdown]
# # Notebook 12: Random Forest Classifier
#
# **Module:** 03 Classical ML
# **Part:** Classification
# **Duration:** ~2 hrs
#
# **Legacy script:** `Digit recognition randomforest.py`
#
# ---
#
# ## Learning Objectives
#
# 1. Apply bagging to classification
# 2. Train RF on digits
# 3. Walk through Digit recognition randomforest.py

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

REPO = Path('../../').resolve()
plt.rcParams['figure.figsize'] = (8, 5)
rng = np.random.default_rng(42)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)
rf.fit(X_train, y_train)
print(f'RF accuracy: {rf.score(X_test, y_test):.4f}')

# %% [markdown]
# ---
#
# ## Summary
#
# Random Forest is a strong default classifier for tabular data.
#
# **Next:** [13_Classification_Model_Evaluation.ipynb](13_Classification_Model_Evaluation.ipynb)
