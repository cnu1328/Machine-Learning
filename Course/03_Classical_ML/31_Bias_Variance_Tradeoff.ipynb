# %% [markdown]
# # Notebook 31: Bias-Variance Tradeoff
#
# **Module:** 03 Classical ML
# **Part:** Model Selection
# **Duration:** ~2 hrs
#
# ---
#
# ## Learning Objectives
#
# 1. Decompose prediction error
# 2. Visualize under/overfitting

# %% [markdown]
# ## Decomposition
#
# $$\text{Error} = \text{Bias}^2 + \text{Variance} + \text{Irreducible Noise}$$
#
# - **High bias:** underfitting (too simple)
# - **High variance:** overfitting (too complex)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

REPO = Path('../../').resolve()
plt.rcParams['figure.figsize'] = (8, 5)
rng = np.random.default_rng(42)

# %%
from sklearn.model_selection import learning_curve

train_sizes, train_scores, val_scores = learning_curve(
    DecisionTreeClassifier(max_depth=6, random_state=42), X_c, y_c,
    train_sizes=np.linspace(0.1, 1.0, 8), cv=5)

plt.plot(train_sizes, train_scores.mean(axis=1), label='Train')
plt.plot(train_sizes, val_scores.mean(axis=1), label='Validation')
plt.xlabel('Training size'); plt.ylabel('Score'); plt.legend(); plt.title('Learning Curve'); plt.show()

# %% [markdown]
# ---
#
# ## Summary
#
# Balance model complexity: too simple = bias, too complex = variance.
#
# **Next:** [32_Hyperparameter_Tuning.ipynb](32_Hyperparameter_Tuning.ipynb)
