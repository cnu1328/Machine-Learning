# %% [markdown]
# # Notebook 10: Support Vector Machines
#
# **Module:** 03 Classical ML
# **Part:** Classification
# **Duration:** ~2.5 hrs
#
# **Legacy script:** `Day - 5 Handwritten_Digit_Recognition.py`
#
# ---
#
# ## Learning Objectives
#
# 1. Understand maximum margin classifier
# 2. Derive hinge loss
# 3. Train SVM on digits (Day - 5)

# %% [markdown]
# ## 1. Mathematical Formulation
#
# Find hyperplane $w^T x + b = 0$ maximizing margin:
#
# $$\min_{w,b} \frac{1}{2}\|w\|^2 \quad \text{s.t.} \quad y_i(w^T x_i + b) \geq 1$$
#
# **Soft margin:** add slack variables $\xi_i$, penalized by $C$.
#
# **Hinge loss:** $L = \max(0, 1 - y_i \hat{y}_i)$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

REPO = Path('../../').resolve()
plt.rcParams['figure.figsize'] = (8, 5)
rng = np.random.default_rng(42)

# %%
from sklearn.svm import SVC
from sklearn.datasets import load_digits

digits = load_digits()
X_train, X_test, y_train, y_test = train_test_split(digits.data, digits.target, test_size=0.2, random_state=42)

svm = SVC(kernel='rbf', C=1.0, gamma='scale')
svm.fit(X_train, y_train)
print(f'SVM accuracy: {svm.score(X_test, y_test):.4f}')

# %% [markdown]
# ---
#
# ## Summary
#
# SVM finds maximum-margin boundary. Kernel trick handles non-linearity.
#
# **Next:** [11_Decision_Tree_Classifier.ipynb](11_Decision_Tree_Classifier.ipynb)
