# %% [markdown]
# # Notebook 32: Hyperparameter Tuning
#
# **Module:** 03 Classical ML
# **Part:** Model Selection
# **Duration:** ~2 hrs
#
# ---
#
# ## Learning Objectives
#
# 1. Grid search and random search
# 2. Tune RF hyperparameters

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

REPO = Path('../../').resolve()
plt.rcParams['figure.figsize'] = (8, 5)
rng = np.random.default_rng(42)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'n_estimators': [50, 100], 'max_depth': [3, 5, 10], 'min_samples_split': [2, 5]}
grid = GridSearchCV(RandomForestClassifier(random_state=42), param_grid, cv=3, scoring='accuracy', n_jobs=-1)
grid.fit(X_c, y_c)
print('Best params:', grid.best_params_)
print('Best CV score:', grid.best_score_:.4f)

# %% [markdown]
# ---
#
# ## Summary
#
# Systematic hyperparameter search beats manual guessing.
#
# **Next:** [33_Isolation_Forest.ipynb](33_Isolation_Forest.ipynb)
