# %% [markdown]
# # Notebook 14: Multi-Algorithm Comparison
#
# **Module:** 03 Classical ML
# **Part:** Classification
# **Duration:** ~2.5 hrs
#
# **Legacy script:** `Day - 10 Breat cancer Detection_VariousMLAlgorithm.py`
#
# ---
#
# ## Learning Objectives
#
# 1. Compare LR, KNN, SVM, DT, RF on same dataset
# 2. Use cross-validation for fair comparison
# 3. Walk through Day - 10 breast cancer script

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

REPO = Path('../../').resolve()
plt.rcParams['figure.figsize'] = (8, 5)
rng = np.random.default_rng(42)

# %%
cancer = pd.read_csv(REPO / 'breat_cancer.csv')
print(cancer.shape)

target = 'diagnosis' if 'diagnosis' in cancer.columns else cancer.columns[-1]
X = cancer.drop(columns=[target]).select_dtypes(include=[np.number]).fillna(0)
y = (cancer[target] == 'M').astype(int) if cancer[target].dtype == object else cancer[target]

from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

models = {
    'LogisticRegression': LogisticRegression(max_iter=1000),
    'KNN': KNeighborsClassifier(),
    'SVM': SVC(),
    'DecisionTree': DecisionTreeClassifier(random_state=42),
    'RandomForest': RandomForestClassifier(random_state=42),
}

for name, model in models.items():
    scores = cross_val_score(model, X, y, cv=5, scoring='accuracy')
    print(f'{name:22s}: {scores.mean():.4f} ± {scores.std():.4f}')

# %% [markdown]
# ---
#
# ## Summary
#
# Always compare models with cross-validation on the same data splits.
#
# **Next:** [15_AdaBoost.ipynb](15_AdaBoost.ipynb)
