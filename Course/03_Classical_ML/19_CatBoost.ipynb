# %% [markdown]
# # Notebook 19: CatBoost
#
# **Module:** 03 Classical ML
# **Part:** Ensemble Methods
# **Duration:** ~2 hrs
#
# ---
#
# ## Learning Objectives
#
# 1. Understand CatBoost
# 2. Train and evaluate
# 3. Know key hyperparameters

# %% [markdown]
# ## 1. Overview
#
# Handles categorical features natively.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

REPO = Path('../../').resolve()
plt.rcParams['figure.figsize'] = (8, 5)
rng = np.random.default_rng(42)

# %%
try:
    import catboost as cb
    cat = cb.CatBoostClassifier(iterations=100, depth=4, random_state=42, verbose=0)
    cat.fit(X_train, y_train)
    print(f'CatBoost accuracy: {cat.score(X_test, y_test):.4f}')
except ImportError:
    print('Install catboost: pip install catboost')

# %% [markdown]
# ## Hyperparameters
#
# See sklearn/xgboost documentation. Key: `n_estimators`, `learning_rate`, `max_depth`.

# %% [markdown]
# ---
#
# ## Summary
#
# CatBoost is a powerful ensemble method for tabular data competitions.
#
# **Next:** [20_CatBoost.ipynb](20_CatBoost.ipynb)
