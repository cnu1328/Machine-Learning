# %% [markdown]
# # Notebook 13: Mask2Former
#
# **Module:** 07 Segmentation
# **Duration:** ~2 hrs
#
# ---
#
# ## Learning Objectives
#
# 1. Understand mask classification paradigm
# 2. Preview universal segmentation

# %% [markdown]
# ## Mask2Former (Cheng et al., 2022)
#
# Predicts **N mask proposals** + class labels — unifies semantic, instance, and panoptic segmentation.
#
# Uses masked attention in transformer decoder.

# %% [markdown]
# ---
#
# ## Summary
#
# Mask2Former unifies all segmentation types via mask classification.
#
# **Next:** [14_SAM.ipynb](14_SAM.ipynb)
